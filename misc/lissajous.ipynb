# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
## APEX limits are 0-0.11rad/s for the angular velocities

# %%
points = 256
t = np.linspace(0,2*np.pi, points)

a= 3
b = 2

x = np.sin(a*t)
y = np.sin(b*t)

plt.plot(x,y)
plt.show()
